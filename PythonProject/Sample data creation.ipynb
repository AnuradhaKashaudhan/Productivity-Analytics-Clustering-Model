# %%
import pandas as pd
import warnings
warnings.filterwarnings('ignore')
# Load only the first 5000 rows from the file
df = pd.read_csv("D:\Python\Datasets\Handled_Training_Data.csv", nrows=5000)

# Save the extracted rows to a new CSV file
df.to_csv("D:/Python/Datasets/first_5000_rows.csv", index=False)
# Out:
# <>:5: SyntaxWarning: invalid escape sequence '\P'
# <>:5: SyntaxWarning: invalid escape sequence '\P'
# C:\Users\Anuradha Kashaudhan\AppData\Local\Temp\ipykernel_9516\1065094500.py:5: SyntaxWarning: invalid escape sequence '\P'
#   df = pd.read_csv("D:\Python\Datasets\Handled_Training_Data.csv", nrows=5000)
